# %% [markdown]
# * Based on https://www.kaggle.com/michaelsnell/conv1d-dpcnn-in-keras/code
# * Paper - http://ai.tencent.com/ailab/media/publications/ACL3-Brady.pdf

# %%
#dpcnn http://ai.tencent.com/ailab/media/publications/ACL3-Brady.pdf
#dpcnn with conv1d, model architecture and all parameters copied from neptune-ml since it's publicly available
#https://github.com/neptune-ml/kaggle-toxic-starter/blob/master/best_configs/fasttext_dpcnn.yaml
#Got it to PLB 0.984 with 10fold cv on local computer after playing with parameters
#Try to improve score on your own local pc or throw it in the blender with the rest of them :)

import os
import gc
import numpy as np
import pandas as pd
import tensorflow as tf
import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold

from keras import backend as K
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
from keras.models import Model
from keras.layers import Input, Dense, Embedding, MaxPooling1D, Conv1D, SpatialDropout1D
from keras.layers import add, Dropout, Activation, PReLU, BatchNormalization, GlobalMaxPooling1D
from keras.preprocessing import text, sequence
from keras.callbacks import Callback
from keras.optimizers import Adam, Nadam
from keras import initializers, regularizers, constraints, callbacks
from keras.callbacks import Callback, CSVLogger, ModelCheckpoint, EarlyStopping
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### Data preparation

# %%
embeddings = 'fasttext' #'glove', 'fasttext

if embeddings == 'fasttext':
    EMBEDDING_FILE = '../data/fasttext/crawl-300d-2M.vec'
else:
    EMBEDDING_FILE = '../data/glove/glove.840B.300d.txt'    

max_features = 100000  #100000 , 30000
maxlen = 200
embed_size = 300
prefix = 'c1' #x, #c1

print(EMBEDDING_FILE)
# Out:
# ../data/fasttext/crawl-300d-2M.vec

# %%
# loading pre-trained word sequences and embedding matrix (see notebook "LSTM + FastText_GloVe + MaxPool")

import pickle

train_feats_path = '../models/{}_train_feat_{}_seq_{}.pkl'.format(prefix, max_features, maxlen)
test_feats_path = '../models/{}_test_feat_{}_seq_{}.pkl'.format(prefix, max_features, maxlen)
embedding_matrix_path = '../models/{}_{}_embedding_matrix_feat_{}.pkl'.format(prefix, embeddings, max_features)
print(train_feats_path)

#pickle.dump(x_train, open(train_feats_path, 'wb'))
#pickle.dump(x_test, open(test_feats_path, 'wb'))
#pickle.dump(embedding_matrix, open(embedding_matrix_path, 'wb'))

x_train = pickle.load(open(train_feats_path, 'rb') )
x_test = pickle.load(open(test_feats_path, 'rb') )
embedding_matrix = pickle.load(open(embedding_matrix_path, 'rb') )

train = pd.read_csv('../data/train.csv')
y_train = train[["toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"]].values
submission = pd.read_csv('../data/sample_submission.csv')

del train
# Out:
# ../models/c1_train_feat_100000_seq_200.pkl

# %%
class RocAucEvaluation(Callback):
    def __init__(self, validation_data=(), interval=1):
        super(Callback, self).__init__()

        self.interval = interval
        self.X_val, self.y_val = validation_data
        self.stopped_epoch = 0
        self.best = 0        

    def on_epoch_end(self, epoch, logs={}):
        if epoch % self.interval == 0:
            y_pred = self.model.predict(self.X_val, verbose=0)
            score = roc_auc_score(self.y_val, y_pred)
            print("\n ROC-AUC - epoch: %d - score: %.6f \n" % (epoch+1, score))

            # stopping condition - ROC stops improving
            if score > self.best:
                self.best = score
            else:
                pass
                #self.stopped_epoch = epoch
                #self.model.stop_training = True
                #print('Epoch %05d: early stopping' % (self.stopped_epoch + 1))    

def schedule(ind):
    a = [0.001, 0.0005, 0.0001, 0.0001]
    return a[ind] if ind<len(a) else a[len(a)-1]

# %% [markdown]
# ### Model

# %%
session_conf = tf.ConfigProto(intra_op_parallelism_threads=4, inter_op_parallelism_threads=4)
K.set_session(tf.Session(graph=tf.get_default_graph(), config=session_conf))

#model
filter_nr = 32
filter_size = 3
max_pool_size = 3
max_pool_strides = 2
dense_nr = 256
spatial_dropout = 0.3
dense_dropout = 0.5
train_embed = False
cnn_depth = 7 #proposed in the paper
conv_kern_reg = regularizers.l2(0.00001)
conv_bias_reg = regularizers.l2(0.00001)

# try:
# spatial_dropout = 0.4
# remove dense dropout
# remove first additional CNN
# add linear activation
# use Conv filter 256

# a repeating block in the CNN
def conv_conv_pool_block(inp):
    pre_act = MaxPooling1D(pool_size=max_pool_size, strides=max_pool_strides)(inp)

    block = Conv1D(filter_nr, kernel_size=filter_size, padding='same', activation='linear', 
                kernel_regularizer=conv_kern_reg, bias_regularizer=conv_bias_reg)(pre_act)
    block = BatchNormalization()(block)
    block = PReLU()(block)
    block = Conv1D(filter_nr, kernel_size=filter_size, padding='same', activation='linear', 
                kernel_regularizer=conv_kern_reg, bias_regularizer=conv_bias_reg)(block)
    block = BatchNormalization()(block)
    block = PReLU()(block)

    return add([block, pre_act])  

def build_model():
    comment = Input(shape=(maxlen,))
    emb_comment = Embedding(max_features, embed_size, weights=[embedding_matrix], trainable=train_embed)(comment)
    emb_comment = SpatialDropout1D(spatial_dropout)(emb_comment)

    block1 = Conv1D(filter_nr, kernel_size=filter_size, padding='same', activation='linear', 
                kernel_regularizer=conv_kern_reg, bias_regularizer=conv_bias_reg)(emb_comment)
    block1 = BatchNormalization()(block1)
    block1 = PReLU()(block1)
    block1 = Conv1D(filter_nr, kernel_size=filter_size, padding='same', activation='linear', 
                kernel_regularizer=conv_kern_reg, bias_regularizer=conv_bias_reg)(block1)
    block1 = BatchNormalization()(block1)
    block1 = PReLU()(block1)

    #we pass embedded comment through conv1d with filter size 1 because it needs to have the same shape as block output
    #if you choose filter_nr = embed_size (300 in this case) you don't have to do this part and can add emb_comment directly to block1_output
    #resize_emb = Conv1D(filter_nr, kernel_size=1, padding='same', activation='linear', 
    #            kernel_regularizer=conv_kern_reg, bias_regularizer=conv_bias_reg)(emb_comment)
    #resize_emb = PReLU()(resize_emb)
    
    resize_emb = Activation('relu')(emb_comment)
    resize_emb = Dense(filter_nr, activation='linear')(resize_emb)    
    block = add([block1, resize_emb])

    for i in range(0, cnn_depth-1):
        block = conv_conv_pool_block(block)

    output = GlobalMaxPooling1D()(block)

    output = Dense(dense_nr, activation='linear')(output)
    output = BatchNormalization()(output)
    output = PReLU()(output)
    output = Dropout(dense_dropout)(output)
    output = Dense(6, activation='sigmoid')(output)

    return Model(comment, output)

# %%
batch_size = 128
epochs = 30

#opt = Nadam(lr=0.001) #optimizer
opt = Adam(lr = 0.001, decay = 0) #Nadam(lr=0.002) #optimizer

model = build_model()
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 200)          0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 200, 300)     30000000    input_1[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_1 (SpatialDro (None, 200, 300)     0           embedding_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 200, 32)      28832       spatial_dropout1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 200, 32)      128         conv1d_1[0][0]
# __________________________________________________________________________________________________
# p_re_lu_1 (PReLU)               (None, 200, 32)      6400        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 200, 32)      3104        p_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 200, 32)      128         conv1d_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 200, 300)     0           spatial_dropout1d_1[0][0]
# __________________________________________________________________________________________________
# p_re_lu_2 (PReLU)               (None, 200, 32)      6400        batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 200, 32)      9632        activation_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 200, 32)      0           p_re_lu_2[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 99, 32)       0           add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 99, 32)       3104        max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 99, 32)       128         conv1d_3[0][0]
# __________________________________________________________________________________________________
# p_re_lu_3 (PReLU)               (None, 99, 32)       3168        batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 99, 32)       3104        p_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 99, 32)       128         conv1d_4[0][0]
# __________________________________________________________________________________________________
# p_re_lu_4 (PReLU)               (None, 99, 32)       3168        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 99, 32)       0           p_re_lu_4[0][0]
#                                                                  max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 49, 32)       0           add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 49, 32)       3104        max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 49, 32)       128         conv1d_5[0][0]
# __________________________________________________________________________________________________
# p_re_lu_5 (PReLU)               (None, 49, 32)       1568        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 49, 32)       3104        p_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 49, 32)       128         conv1d_6[0][0]
# __________________________________________________________________________________________________
# p_re_lu_6 (PReLU)               (None, 49, 32)       1568        batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 49, 32)       0           p_re_lu_6[0][0]
#                                                                  max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 24, 32)       0           add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 24, 32)       3104        max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 24, 32)       128         conv1d_7[0][0]
# __________________________________________________________________________________________________
# p_re_lu_7 (PReLU)               (None, 24, 32)       768         batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 24, 32)       3104        p_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 24, 32)       128         conv1d_8[0][0]
# __________________________________________________________________________________________________
# p_re_lu_8 (PReLU)               (None, 24, 32)       768         batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 24, 32)       0           p_re_lu_8[0][0]
#                                                                  max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 11, 32)       0           add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 11, 32)       3104        max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 11, 32)       128         conv1d_9[0][0]
# __________________________________________________________________________________________________
# p_re_lu_9 (PReLU)               (None, 11, 32)       352         batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 11, 32)       3104        p_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 11, 32)       128         conv1d_10[0][0]
# __________________________________________________________________________________________________
# p_re_lu_10 (PReLU)              (None, 11, 32)       352         batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 11, 32)       0           p_re_lu_10[0][0]
#                                                                  max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 5, 32)        0           add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 5, 32)        3104        max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 5, 32)        128         conv1d_11[0][0]
# __________________________________________________________________________________________________
# p_re_lu_11 (PReLU)              (None, 5, 32)        160         batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 5, 32)        3104        p_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 5, 32)        128         conv1d_12[0][0]
# __________________________________________________________________________________________________
# p_re_lu_12 (PReLU)              (None, 5, 32)        160         batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 5, 32)        0           p_re_lu_12[0][0]
#                                                                  max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 2, 32)        0           add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 2, 32)        3104        max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 2, 32)        128         conv1d_13[0][0]
# __________________________________________________________________________________________________
# p_re_lu_13 (PReLU)              (None, 2, 32)        64          batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 2, 32)        3104        p_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 2, 32)        128         conv1d_14[0][0]
# __________________________________________________________________________________________________
# p_re_lu_14 (PReLU)              (None, 2, 32)        64          batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 2, 32)        0           p_re_lu_14[0][0]
#                                                                  max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_1 (GlobalM (None, 32)           0           add_7[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          8448        global_max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 256)          1024        dense_2[0][0]
# __________________________________________________________________________________________________
# p_re_lu_15 (PReLU)              (None, 256)          256         batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           p_re_lu_15[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 6)            1542        dropout_1[0][0]
# ==================================================================================================
# Total params: 30,116,838
# Trainable params: 115,430
# Non-trainable params: 30,001,408
# __________________________________________________________________________________________________

# %%
X_tra, X_val, y_tra, y_val = train_test_split(x_train, y_train, train_size=0.95, random_state=233)
ra_val = RocAucEvaluation(validation_data=(X_val, y_val), interval=1)
checkPoint = ModelCheckpoint('../snapshots/weights.{epoch:02d}-{val_loss:.2f}.hdf5')
csv_logger = CSVLogger('../training.log')
lr = callbacks.LearningRateScheduler(schedule)

model.fit(X_tra, y_tra, batch_size=batch_size, epochs=epochs, validation_data=(X_val, y_val), callbacks = [lr, ra_val] ,verbose=1)

# %% [markdown]
# ### Stratified k-fold learning

# %%
## Stratified k-fold training

n_folds = 10
batch_size = 128
epochs = 30
predict_batch_size = 1024
run_id = 'dpcnn_fasttext_128'
opt = Adam(lr = 0.005, decay = 0) #Nadam(lr=0.002) #optimizer

kfold = StratifiedKFold(n_splits = 20, shuffle = True, random_state = 32)

csv_logger = CSVLogger('../training.log')
early_stop = EarlyStopping(verbose=2, monitor = "val_loss", mode = "min", patience = 5)

pred = np.zeros((x_test.shape[0], 6))
y_packed = np.packbits(y_train, axis=1)

for i, (train_idx, valid_idx) in enumerate(kfold.split(x_train, y_packed)):
    print("Running fold {} / {}".format(i + 1, n_folds))
    print("Training / Valid set counts {} / {}".format(train_idx.shape, valid_idx.shape))

    model = None    
    model = build_model()
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
    #model.summary()
    
    xs_train, ys_train = x_train[train_idx], y_train[train_idx] 
    xs_valid, ys_valid = x_train[valid_idx], y_train[valid_idx]

    #check_point = ModelCheckpoint('../snapshots/' + run_id + '_fold_' + str(i) + '_weights.{epoch:02d}-{val_loss:.2f}.hdf5')
    roc_auc = RocAucEvaluation(validation_data=(xs_valid, ys_valid), interval=1)
    check_point = ModelCheckpoint('../snapshots/' + run_id + '_fold_' + str(i) +'.hdf5', monitor = "val_loss", 
                                  verbose = 1, save_best_only = True, mode = "min")

    # training
    history = model.fit(xs_train, ys_train, batch_size = batch_size, epochs = epochs, validation_data = (xs_valid, ys_valid), 
                          verbose = 2, callbacks=[roc_auc, csv_logger, check_point, early_stop])        
    # predict
    pred += model.predict(x_test, batch_size = predict_batch_size, verbose = 1)

    if (i + 1) == n_folds: break    
    
y_pred = pred/n_folds
# Out:
# Running fold 1 / 10
# Training / Valid set counts (151582,) / (7989,)
# Train on 151582 samples, validate on 7989 samples
# Epoch 1/30
#  - 62s - loss: 0.0668 - acc: 0.9783 - val_loss: 0.0549 - val_acc: 0.9813
#
#  ROC-AUC - epoch: 1 - score: 0.976472
#
#
# Epoch 00001: val_loss improved from inf to 0.05492, saving model to ../snapshots/dpcnn_fasttext_128_fold_0.hdf5
# Epoch 2/30
#  - 56s - loss: 0.0555 - acc: 0.9813 - val_loss: 0.0522 - val_acc: 0.9824
#
#  ROC-AUC - epoch: 2 - score: 0.979186
#
#
# Epoch 00002: val_loss improved from 0.05492 to 0.05221, saving model to ../snapshots/dpcnn_fasttext_128_fold_0.hdf5
# Epoch 3/30
#  - 56s - loss: 0.0538 - acc: 0.9815 - val_loss: 0.0531 - val_acc: 0.9822
#
#  ROC-AUC - epoch: 3 - score: 0.981561
#
#
# Epoch 00003: val_loss did not improve
# Epoch 4/30
#  - 56s - loss: 0.0529 - acc: 0.9820 - val_loss: 0.0506 - val_acc: 0.9828
#
#  ROC-AUC - epoch: 4 - score: 0.983929
#
#
# Epoch 00004: val_loss improved from 0.05221 to 0.05055, saving model to ../snapshots/dpcnn_fasttext_128_fold_0.hdf5
# Epoch 5/30
#  - 56s - loss: 0.0519 - acc: 0.9825 - val_loss: 0.0509 - val_acc: 0.9827
#
#  ROC-AUC - epoch: 5 - score: 0.984759
#
#
# Epoch 00005: val_loss did not improve
# Epoch 6/30
#  - 56s - loss: 0.0511 - acc: 0.9826 - val_loss: 0.0528 - val_acc: 0.9817
#
#  ROC-AUC - epoch: 6 - score: 0.985728
#
#
# Epoch 00006: val_loss did not improve
# Epoch 7/30
#  - 56s - loss: 0.0501 - acc: 0.9828 - val_loss: 0.0503 - val_acc: 0.9830
#
#  ROC-AUC - epoch: 7 - score: 0.986685
#
#
# Epoch 00007: val_loss improved from 0.05055 to 0.05032, saving model to ../snapshots/dpcnn_fasttext_128_fold_0.hdf5
# Epoch 8/30
#  - 56s - loss: 0.0499 - acc: 0.9828 - val_loss: 0.0532 - val_acc: 0.9822
#
#  ROC-AUC - epoch: 8 - score: 0.987016
#
#
# Epoch 00008: val_loss did not improve
# Epoch 9/30
#  - 56s - loss: 0.0488 - acc: 0.9831 - val_loss: 0.0482 - val_acc: 0.9834
#
#  ROC-AUC - epoch: 9 - score: 0.987736
#
#
# Epoch 00009: val_loss improved from 0.05032 to 0.04819, saving model to ../snapshots/dpcnn_fasttext_128_fold_0.hdf5
# Epoch 10/30
#  - 56s - loss: 0.0483 - acc: 0.9833 - val_loss: 0.0505 - val_acc: 0.9829
#
#  ROC-AUC - epoch: 10 - score: 0.986838
#
#
# Epoch 00010: val_loss did not improve
# Epoch 11/30
#  - 56s - loss: 0.0481 - acc: 0.9833 - val_loss: 0.0488 - val_acc: 0.9830
#
#  ROC-AUC - epoch: 11 - score: 0.986087
#
#
# Epoch 00011: val_loss did not improve
# Epoch 12/30
#  - 56s - loss: 0.0477 - acc: 0.9834 - val_loss: 0.0486 - val_acc: 0.9830
#
#  ROC-AUC - epoch: 12 - score: 0.986565
#
#
# Epoch 00012: val_loss did not improve
# Epoch 13/30
#  - 56s - loss: 0.0472 - acc: 0.9834 - val_loss: 0.0567 - val_acc: 0.9830
#
#  ROC-AUC - epoch: 13 - score: 0.983620
#
#
# Epoch 00013: val_loss did not improve
# Epoch 14/30
#  - 57s - loss: 0.0468 - acc: 0.9835 - val_loss: 0.0560 - val_acc: 0.9816
#
#  ROC-AUC - epoch: 14 - score: 0.985665
#
#
# Epoch 00014: val_loss did not improve
# Epoch 00014: early stopping
# 153164/153164 [==============================] - 9s 59us/step
# Running fold 2 / 10
# Training / Valid set counts (151588,) / (7983,)
# Train on 151588 samples, validate on 7983 samples
# Epoch 1/30
#  - 63s - loss: 0.0717 - acc: 0.9790 - val_loss: 0.0556 - val_acc: 0.9818
#
#  ROC-AUC - epoch: 1 - score: 0.972943
#
#
# Epoch 00001: val_loss improved from inf to 0.05559, saving model to ../snapshots/dpcnn_fasttext_128_fold_1.hdf5
# Epoch 2/30
#  - 57s - loss: 0.0569 - acc: 0.9811 - val_loss: 0.0522 - val_acc: 0.9823
#
#  ROC-AUC - epoch: 2 - score: 0.974919
#
#
# Epoch 00002: val_loss improved from 0.05559 to 0.05220, saving model to ../snapshots/dpcnn_fasttext_128_fold_1.hdf5
# Epoch 3/30
#  - 58s - loss: 0.0544 - acc: 0.9816 - val_loss: 0.0525 - val_acc: 0.9820
#
#  ROC-AUC - epoch: 3 - score: 0.975606
#
#
# Epoch 00003: val_loss did not improve
# Epoch 4/30
#  - 57s - loss: 0.0529 - acc: 0.9819 - val_loss: 0.0511 - val_acc: 0.9826
#
#  ROC-AUC - epoch: 4 - score: 0.978475
#
#
# Epoch 00004: val_loss improved from 0.05220 to 0.05108, saving model to ../snapshots/dpcnn_fasttext_128_fold_1.hdf5
# Epoch 5/30
#  - 58s - loss: 0.0513 - acc: 0.9822 - val_loss: 0.0496 - val_acc: 0.9828
#
#  ROC-AUC - epoch: 5 - score: 0.980965
#
#
# Epoch 00005: val_loss improved from 0.05108 to 0.04961, saving model to ../snapshots/dpcnn_fasttext_128_fold_1.hdf5
# Epoch 6/30
#  - 58s - loss: 0.0508 - acc: 0.9826 - val_loss: 0.0492 - val_acc: 0.9825
#
#  ROC-AUC - epoch: 6 - score: 0.983120
#
#
# Epoch 00006: val_loss improved from 0.04961 to 0.04920, saving model to ../snapshots/dpcnn_fasttext_128_fold_1.hdf5
# Epoch 7/30
#  - 58s - loss: 0.0501 - acc: 0.9827 - val_loss: 0.0543 - val_acc: 0.9817
#
#  ROC-AUC - epoch: 7 - score: 0.980850
#
#
# Epoch 00007: val_loss did not improve
# Epoch 8/30
#  - 59s - loss: 0.0494 - acc: 0.9828 - val_loss: 0.0515 - val_acc: 0.9816
#
#  ROC-AUC - epoch: 8 - score: 0.982646
#
#
# Epoch 00008: val_loss did not improve
# Epoch 9/30
#  - 59s - loss: 0.0487 - acc: 0.9830 - val_loss: 0.0489 - val_acc: 0.9827
#
#  ROC-AUC - epoch: 9 - score: 0.983771
#
#
# Epoch 00009: val_loss improved from 0.04920 to 0.04892, saving model to ../snapshots/dpcnn_fasttext_128_fold_1.hdf5
# Epoch 10/30
#  - 60s - loss: 0.0484 - acc: 0.9830 - val_loss: 0.0550 - val_acc: 0.9825
#
#  ROC-AUC - epoch: 10 - score: 0.981780
#
#
# Epoch 00010: val_loss did not improve
# Epoch 11/30
#  - 60s - loss: 0.0479 - acc: 0.9832 - val_loss: 0.0508 - val_acc: 0.9821
#
#  ROC-AUC - epoch: 11 - score: 0.983572
#
#
# Epoch 00011: val_loss did not improve
# Epoch 12/30
#  - 60s - loss: 0.0471 - acc: 0.9833 - val_loss: 0.0493 - val_acc: 0.9826
#
#  ROC-AUC - epoch: 12 - score: 0.984095
#
#
# Epoch 00012: val_loss did not improve
# Epoch 13/30
#  - 60s - loss: 0.0470 - acc: 0.9833 - val_loss: 0.0479 - val_acc: 0.9829
#
#  ROC-AUC - epoch: 13 - score: 0.984605
#
#
# Epoch 00013: val_loss improved from 0.04892 to 0.04786, saving model to ../snapshots/dpcnn_fasttext_128_fold_1.hdf5
# Epoch 14/30
#  - 60s - loss: 0.0467 - acc: 0.9834 - val_loss: 0.0497 - val_acc: 0.9828
#
#  ROC-AUC - epoch: 14 - score: 0.984985
#
#
# Epoch 00014: val_loss did not improve
# Epoch 15/30
#  - 60s - loss: 0.0464 - acc: 0.9833 - val_loss: 0.0469 - val_acc: 0.9832
#
#  ROC-AUC - epoch: 15 - score: 0.985393
#
#
# Epoch 00015: val_loss improved from 0.04786 to 0.04688, saving model to ../snapshots/dpcnn_fasttext_128_fold_1.hdf5
# Epoch 16/30
#  - 60s - loss: 0.0461 - acc: 0.9836 - val_loss: 0.0502 - val_acc: 0.9821
#
#  ROC-AUC - epoch: 16 - score: 0.985717
#
#
# Epoch 00016: val_loss did not improve
# Epoch 17/30
#  - 60s - loss: 0.0456 - acc: 0.9837 - val_loss: 0.0466 - val_acc: 0.9827
#
#  ROC-AUC - epoch: 17 - score: 0.985703
#
#
# Epoch 00017: val_loss improved from 0.04688 to 0.04662, saving model to ../snapshots/dpcnn_fasttext_128_fold_1.hdf5
# Epoch 18/30
#  - 61s - loss: 0.0458 - acc: 0.9835 - val_loss: 0.0489 - val_acc: 0.9827
#
#  ROC-AUC - epoch: 18 - score: 0.985476
#
#
# Epoch 00018: val_loss did not improve
# Epoch 19/30
#  - 60s - loss: 0.0459 - acc: 0.9837 - val_loss: 0.0477 - val_acc: 0.9833
#
#  ROC-AUC - epoch: 19 - score: 0.984213
#
#
# Epoch 00019: val_loss did not improve
# Epoch 20/30
#  - 60s - loss: 0.0450 - acc: 0.9838 - val_loss: 0.0489 - val_acc: 0.9826
#
#  ROC-AUC - epoch: 20 - score: 0.984076
#
#
# Epoch 00020: val_loss did not improve
# Epoch 21/30
#  - 60s - loss: 0.0450 - acc: 0.9838 - val_loss: 0.0473 - val_acc: 0.9831
#
#  ROC-AUC - epoch: 21 - score: 0.985726
#
#
# Epoch 00021: val_loss did not improve
# Epoch 22/30
#  - 60s - loss: 0.0448 - acc: 0.9839 - val_loss: 0.0468 - val_acc: 0.9830
#
#  ROC-AUC - epoch: 22 - score: 0.985494
#
#
# Epoch 00022: val_loss did not improve
# Epoch 00022: early stopping
# 153164/153164 [==============================] - 10s 65us/step
# Running fold 3 / 10
# Training / Valid set counts (151584,) / (7987,)
# Train on 151584 samples, validate on 7987 samples
# Epoch 1/30
#  - 69s - loss: 0.0748 - acc: 0.9786 - val_loss: 0.0582 - val_acc: 0.9815
#
#  ROC-AUC - epoch: 1 - score: 0.974498
#
#
# Epoch 00001: val_loss improved from inf to 0.05825, saving model to ../snapshots/dpcnn_fasttext_128_fold_2.hdf5
# Epoch 2/30
#  - 61s - loss: 0.0577 - acc: 0.9810 - val_loss: 0.0553 - val_acc: 0.9809
#
#  ROC-AUC - epoch: 2 - score: 0.977211
#
#
# Epoch 00002: val_loss improved from 0.05825 to 0.05534, saving model to ../snapshots/dpcnn_fasttext_128_fold_2.hdf5
# Epoch 3/30
#  - 61s - loss: 0.0553 - acc: 0.9815 - val_loss: 0.0545 - val_acc: 0.9817
#
#  ROC-AUC - epoch: 3 - score: 0.978578
#
#
# Epoch 00003: val_loss improved from 0.05534 to 0.05451, saving model to ../snapshots/dpcnn_fasttext_128_fold_2.hdf5
# Epoch 4/30
#  - 61s - loss: 0.0531 - acc: 0.9820 - val_loss: 0.0519 - val_acc: 0.9829
#
#  ROC-AUC - epoch: 4 - score: 0.980774
#
#
# Epoch 00004: val_loss improved from 0.05451 to 0.05192, saving model to ../snapshots/dpcnn_fasttext_128_fold_2.hdf5
# Epoch 5/30
#  - 61s - loss: 0.0519 - acc: 0.9822 - val_loss: 0.0529 - val_acc: 0.9822
#
#  ROC-AUC - epoch: 5 - score: 0.983379
#
#
# Epoch 00005: val_loss did not improve
# Epoch 6/30
#  - 59s - loss: 0.0507 - acc: 0.9826 - val_loss: 0.0690 - val_acc: 0.9780
#
#  ROC-AUC - epoch: 6 - score: 0.980911
#
#
# Epoch 00006: val_loss did not improve
# Epoch 7/30
#  - 57s - loss: 0.0499 - acc: 0.9828 - val_loss: 0.0494 - val_acc: 0.9828
#
#  ROC-AUC - epoch: 7 - score: 0.986149
#
#
# Epoch 00007: val_loss improved from 0.05192 to 0.04936, saving model to ../snapshots/dpcnn_fasttext_128_fold_2.hdf5
# Epoch 8/30
#  - 57s - loss: 0.0493 - acc: 0.9830 - val_loss: 0.0511 - val_acc: 0.9821
#
#  ROC-AUC - epoch: 8 - score: 0.986594
#
#
# Epoch 00008: val_loss did not improve
# Epoch 9/30
#  - 56s - loss: 0.0488 - acc: 0.9831 - val_loss: 0.0494 - val_acc: 0.9831
#
#  ROC-AUC - epoch: 9 - score: 0.986286
#
#
# Epoch 00009: val_loss did not improve
# Epoch 10/30
#  - 56s - loss: 0.0478 - acc: 0.9833 - val_loss: 0.0506 - val_acc: 0.9827
#
#  ROC-AUC - epoch: 10 - score: 0.987170
#
#
# Epoch 00010: val_loss did not improve
# Epoch 11/30
#  - 56s - loss: 0.0475 - acc: 0.9833 - val_loss: 0.0488 - val_acc: 0.9828
#
#  ROC-AUC - epoch: 11 - score: 0.987133
#
#
# Epoch 00011: val_loss improved from 0.04936 to 0.04876, saving model to ../snapshots/dpcnn_fasttext_128_fold_2.hdf5
# Epoch 12/30
#  - 56s - loss: 0.0474 - acc: 0.9834 - val_loss: 0.0480 - val_acc: 0.9828
#
#  ROC-AUC - epoch: 12 - score: 0.987386
#
#
# Epoch 00012: val_loss improved from 0.04876 to 0.04800, saving model to ../snapshots/dpcnn_fasttext_128_fold_2.hdf5
# Epoch 13/30
#  - 57s - loss: 0.0476 - acc: 0.9833 - val_loss: 0.0535 - val_acc: 0.9827
#
#  ROC-AUC - epoch: 13 - score: 0.987387
#
#
# Epoch 00013: val_loss did not improve
# Epoch 14/30
#  - 57s - loss: 0.0463 - acc: 0.9834 - val_loss: 0.0493 - val_acc: 0.9838
#
#  ROC-AUC - epoch: 14 - score: 0.988065
#
#
# Epoch 00014: val_loss did not improve
# Epoch 15/30
#  - 57s - loss: 0.0461 - acc: 0.9836 - val_loss: 0.0479 - val_acc: 0.9840
#
#  ROC-AUC - epoch: 15 - score: 0.987886
#
#
# Epoch 00015: val_loss improved from 0.04800 to 0.04786, saving model to ../snapshots/dpcnn_fasttext_128_fold_2.hdf5
# Epoch 16/30
#  - 57s - loss: 0.0460 - acc: 0.9837 - val_loss: 0.0493 - val_acc: 0.9831
#
#  ROC-AUC - epoch: 16 - score: 0.988601
#
#
# Epoch 00016: val_loss did not improve
# Epoch 17/30
#  - 57s - loss: 0.0455 - acc: 0.9838 - val_loss: 0.0525 - val_acc: 0.9815
#
#  ROC-AUC - epoch: 17 - score: 0.988172
#
#
# Epoch 00017: val_loss did not improve
# Epoch 18/30
#  - 57s - loss: 0.0454 - acc: 0.9836 - val_loss: 0.0492 - val_acc: 0.9833
#
#  ROC-AUC - epoch: 18 - score: 0.987545
#
#
# Epoch 00018: val_loss did not improve
# Epoch 19/30
#  - 57s - loss: 0.0452 - acc: 0.9837 - val_loss: 0.0474 - val_acc: 0.9835
#
#  ROC-AUC - epoch: 19 - score: 0.988878
#
#
# Epoch 00019: val_loss improved from 0.04786 to 0.04736, saving model to ../snapshots/dpcnn_fasttext_128_fold_2.hdf5
# Epoch 20/30
#  - 57s - loss: 0.0450 - acc: 0.9839 - val_loss: 0.0487 - val_acc: 0.9836
#
#  ROC-AUC - epoch: 20 - score: 0.988266
#
#
# Epoch 00020: val_loss did not improve
# Epoch 21/30
#  - 57s - loss: 0.0448 - acc: 0.9839 - val_loss: 0.0476 - val_acc: 0.9835
#
#  ROC-AUC - epoch: 21 - score: 0.988435
#
#
# Epoch 00021: val_loss did not improve
# Epoch 22/30
#  - 57s - loss: 0.0446 - acc: 0.9839 - val_loss: 0.0490 - val_acc: 0.9834
#
#  ROC-AUC - epoch: 22 - score: 0.986961
#
#
# Epoch 00022: val_loss did not improve
# Epoch 23/30
#  - 57s - loss: 0.0446 - acc: 0.9838 - val_loss: 0.0479 - val_acc: 0.9827
#
#  ROC-AUC - epoch: 23 - score: 0.988408
#
#
# Epoch 00023: val_loss did not improve
# Epoch 24/30
#  - 56s - loss: 0.0444 - acc: 0.9840 - val_loss: 0.0474 - val_acc: 0.9836
#
#  ROC-AUC - epoch: 24 - score: 0.988447
#
#
# Epoch 00024: val_loss did not improve
# Epoch 00024: early stopping
# 153164/153164 [==============================] - 9s 57us/step
# Running fold 4 / 10
# Training / Valid set counts (151588,) / (7983,)
# Train on 151588 samples, validate on 7983 samples
# Epoch 1/30
#  - 64s - loss: 0.0722 - acc: 0.9791 - val_loss: 0.0566 - val_acc: 0.9809
#
#  ROC-AUC - epoch: 1 - score: 0.973689
#
#
# Epoch 00001: val_loss improved from inf to 0.05660, saving model to ../snapshots/dpcnn_fasttext_128_fold_3.hdf5
# Epoch 2/30
#  - 57s - loss: 0.0576 - acc: 0.9811 - val_loss: 0.0542 - val_acc: 0.9819
#
#  ROC-AUC - epoch: 2 - score: 0.977636
#
#
# Epoch 00002: val_loss improved from 0.05660 to 0.05424, saving model to ../snapshots/dpcnn_fasttext_128_fold_3.hdf5
# Epoch 3/30
#  - 57s - loss: 0.0551 - acc: 0.9815 - val_loss: 0.0542 - val_acc: 0.9821
#
#  ROC-AUC - epoch: 3 - score: 0.978070
#
#
# Epoch 00003: val_loss improved from 0.05424 to 0.05422, saving model to ../snapshots/dpcnn_fasttext_128_fold_3.hdf5
# Epoch 4/30
#  - 57s - loss: 0.0531 - acc: 0.9821 - val_loss: 0.0495 - val_acc: 0.9831
#
#  ROC-AUC - epoch: 4 - score: 0.983105
#
#
# Epoch 00004: val_loss improved from 0.05422 to 0.04950, saving model to ../snapshots/dpcnn_fasttext_128_fold_3.hdf5
# Epoch 5/30
#  - 58s - loss: 0.0520 - acc: 0.9821 - val_loss: 0.0493 - val_acc: 0.9828
#
#  ROC-AUC - epoch: 5 - score: 0.982579
#
#
# Epoch 00005: val_loss improved from 0.04950 to 0.04931, saving model to ../snapshots/dpcnn_fasttext_128_fold_3.hdf5
# Epoch 6/30
#  - 58s - loss: 0.0507 - acc: 0.9826 - val_loss: 0.0490 - val_acc: 0.9831
#
#  ROC-AUC - epoch: 6 - score: 0.984078
#
#
# Epoch 00006: val_loss improved from 0.04931 to 0.04898, saving model to ../snapshots/dpcnn_fasttext_128_fold_3.hdf5
# Epoch 7/30
#  - 58s - loss: 0.0499 - acc: 0.9829 - val_loss: 0.0477 - val_acc: 0.9833
#
#  ROC-AUC - epoch: 7 - score: 0.985050
#
#
# Epoch 00007: val_loss improved from 0.04898 to 0.04768, saving model to ../snapshots/dpcnn_fasttext_128_fold_3.hdf5
# Epoch 8/30
#  - 58s - loss: 0.0498 - acc: 0.9829 - val_loss: 0.0487 - val_acc: 0.9831
#
#  ROC-AUC - epoch: 8 - score: 0.986317
#
#
# Epoch 00008: val_loss did not improve
# Epoch 9/30
#  - 58s - loss: 0.0486 - acc: 0.9831 - val_loss: 0.0483 - val_acc: 0.9830
#
#  ROC-AUC - epoch: 9 - score: 0.986219
#
#
# Epoch 00009: val_loss did not improve
# Epoch 10/30
#  - 58s - loss: 0.0483 - acc: 0.9831 - val_loss: 0.0477 - val_acc: 0.9828
#
#  ROC-AUC - epoch: 10 - score: 0.986748
#
#
# Epoch 00010: val_loss improved from 0.04768 to 0.04767, saving model to ../snapshots/dpcnn_fasttext_128_fold_3.hdf5
# Epoch 11/30
#  - 58s - loss: 0.0478 - acc: 0.9833 - val_loss: 0.0482 - val_acc: 0.9830
#
#  ROC-AUC - epoch: 11 - score: 0.986364
#
#
# Epoch 00011: val_loss did not improve
# Epoch 12/30
#  - 58s - loss: 0.0472 - acc: 0.9835 - val_loss: 0.0489 - val_acc: 0.9830
#
#  ROC-AUC - epoch: 12 - score: 0.986385
#
#
# Epoch 00012: val_loss did not improve
# Epoch 13/30
#  - 58s - loss: 0.0468 - acc: 0.9835 - val_loss: 0.0479 - val_acc: 0.9832
#
#  ROC-AUC - epoch: 13 - score: 0.986158
#
#
# Epoch 00013: val_loss did not improve
# Epoch 14/30
#  - 58s - loss: 0.0474 - acc: 0.9835 - val_loss: 0.0521 - val_acc: 0.9831
#
#  ROC-AUC - epoch: 14 - score: 0.982129
#
#
# Epoch 00014: val_loss did not improve
# Epoch 15/30
#  - 58s - loss: 0.0467 - acc: 0.9836 - val_loss: 0.0492 - val_acc: 0.9820
#
#  ROC-AUC - epoch: 15 - score: 0.987258
#
#
# Epoch 00015: val_loss did not improve
# Epoch 00015: early stopping
# 153164/153164 [==============================] - 9s 58us/step
# Running fold 5 / 10
# Training / Valid set counts (151591,) / (7980,)
# Train on 151591 samples, validate on 7980 samples
# Epoch 1/30
#  - 67s - loss: 0.0732 - acc: 0.9790 - val_loss: 0.0528 - val_acc: 0.9825
#
#  ROC-AUC - epoch: 1 - score: 0.977669
#
#
# Epoch 00001: val_loss improved from inf to 0.05275, saving model to ../snapshots/dpcnn_fasttext_128_fold_4.hdf5
# Epoch 2/30
#  - 58s - loss: 0.0567 - acc: 0.9813 - val_loss: 0.0495 - val_acc: 0.9830
#
#  ROC-AUC - epoch: 2 - score: 0.980386
#
#
# Epoch 00002: val_loss improved from 0.05275 to 0.04948, saving model to ../snapshots/dpcnn_fasttext_128_fold_4.hdf5
# Epoch 3/30
#  - 58s - loss: 0.0539 - acc: 0.9817 - val_loss: 0.0473 - val_acc: 0.9835
#
#  ROC-AUC - epoch: 3 - score: 0.983212
#
#
# Epoch 00003: val_loss improved from 0.04948 to 0.04727, saving model to ../snapshots/dpcnn_fasttext_128_fold_4.hdf5
# Epoch 4/30
#  - 58s - loss: 0.0525 - acc: 0.9822 - val_loss: 0.0488 - val_acc: 0.9827
#  ROC-AUC - epoch: 4 - score: 0.983190
#
#
# Epoch 00004: val_loss did not improve
# Epoch 5/30
#  - 58s - loss: 0.0511 - acc: 0.9825 - val_loss: 0.0470 - val_acc: 0.9836
#
#  ROC-AUC - epoch: 5 - score: 0.982055
#
#
# Epoch 00005: val_loss improved from 0.04727 to 0.04701, saving model to ../snapshots/dpcnn_fasttext_128_fold_4.hdf5
# Epoch 6/30
#  - 58s - loss: 0.0504 - acc: 0.9828 - val_loss: 0.0474 - val_acc: 0.9839
#
#  ROC-AUC - epoch: 6 - score: 0.984157
#
#
# Epoch 00006: val_loss did not improve
# Epoch 7/30
#  - 57s - loss: 0.0497 - acc: 0.9829 - val_loss: 0.0483 - val_acc: 0.9837
#
#  ROC-AUC - epoch: 7 - score: 0.985074
#
#
# Epoch 00007: val_loss did not improve
# Epoch 8/30
#  - 57s - loss: 0.0491 - acc: 0.9829 - val_loss: 0.0489 - val_acc: 0.9838
#
#  ROC-AUC - epoch: 8 - score: 0.982512
#
#
# Epoch 00008: val_loss did not improve
# Epoch 9/30
#  - 57s - loss: 0.0487 - acc: 0.9833 - val_loss: 0.0482 - val_acc: 0.9831
#
#  ROC-AUC - epoch: 9 - score: 0.982753
#
#
# Epoch 00009: val_loss did not improve
# Epoch 10/30
#  - 57s - loss: 0.0484 - acc: 0.9832 - val_loss: 0.0480 - val_acc: 0.9827
#
#  ROC-AUC - epoch: 10 - score: 0.984264
#
#
# Epoch 00010: val_loss did not improve
# Epoch 00010: early stopping
# 153164/153164 [==============================] - 9s 58us/step
# Running fold 6 / 10
# Training / Valid set counts (151576,) / (7995,)
# Train on 151576 samples, validate on 7995 samples
# Epoch 1/30
#  - 68s - loss: 0.0732 - acc: 0.9788 - val_loss: 0.0560 - val_acc: 0.9815
#
#  ROC-AUC - epoch: 1 - score: 0.977274
#
#
# Epoch 00001: val_loss improved from inf to 0.05599, saving model to ../snapshots/dpcnn_fasttext_128_fold_5.hdf5
# Epoch 2/30
#  - 58s - loss: 0.0574 - acc: 0.9810 - val_loss: 0.0522 - val_acc: 0.9817
#
#  ROC-AUC - epoch: 2 - score: 0.978959
#
#
# Epoch 00002: val_loss improved from 0.05599 to 0.05224, saving model to ../snapshots/dpcnn_fasttext_128_fold_5.hdf5
# Epoch 3/30
#  - 57s - loss: 0.0540 - acc: 0.9815 - val_loss: 0.0517 - val_acc: 0.9821
#
#  ROC-AUC - epoch: 3 - score: 0.982535
#
#
# Epoch 00003: val_loss improved from 0.05224 to 0.05174, saving model to ../snapshots/dpcnn_fasttext_128_fold_5.hdf5
# Epoch 4/30
#  - 57s - loss: 0.0524 - acc: 0.9820 - val_loss: 0.0533 - val_acc: 0.9821
#
#  ROC-AUC - epoch: 4 - score: 0.980634
#
#
# Epoch 00004: val_loss did not improve
# Epoch 5/30
#  - 57s - loss: 0.0513 - acc: 0.9823 - val_loss: 0.0501 - val_acc: 0.9825
#
#  ROC-AUC - epoch: 5 - score: 0.984005
#
#
# Epoch 00005: val_loss improved from 0.05174 to 0.05013, saving model to ../snapshots/dpcnn_fasttext_128_fold_5.hdf5
# Epoch 6/30
#  - 57s - loss: 0.0501 - acc: 0.9826 - val_loss: 0.0632 - val_acc: 0.9801
#
#  ROC-AUC - epoch: 6 - score: 0.982817
#
#
# Epoch 00006: val_loss did not improve
# Epoch 7/30
#  - 58s - loss: 0.0494 - acc: 0.9828 - val_loss: 0.0525 - val_acc: 0.9817
#
#  ROC-AUC - epoch: 7 - score: 0.983568
#
#
# Epoch 00007: val_loss did not improve
# Epoch 8/30
#  - 57s - loss: 0.0490 - acc: 0.9828 - val_loss: 0.0492 - val_acc: 0.9816
#
#  ROC-AUC - epoch: 8 - score: 0.985306
#
#
# Epoch 00008: val_loss improved from 0.05013 to 0.04920, saving model to ../snapshots/dpcnn_fasttext_128_fold_5.hdf5
# Epoch 9/30
#  - 57s - loss: 0.0485 - acc: 0.9830 - val_loss: 0.0486 - val_acc: 0.9824
#
#  ROC-AUC - epoch: 9 - score: 0.985281
#
#
# Epoch 00009: val_loss improved from 0.04920 to 0.04865, saving model to ../snapshots/dpcnn_fasttext_128_fold_5.hdf5
# Epoch 10/30
#  - 57s - loss: 0.0478 - acc: 0.9832 - val_loss: 0.0475 - val_acc: 0.9832
#
#  ROC-AUC - epoch: 10 - score: 0.984372
#
#
# Epoch 00010: val_loss improved from 0.04865 to 0.04754, saving model to ../snapshots/dpcnn_fasttext_128_fold_5.hdf5
# Epoch 11/30
#  - 57s - loss: 0.0475 - acc: 0.9832 - val_loss: 0.0505 - val_acc: 0.9827
#
#  ROC-AUC - epoch: 11 - score: 0.983916
#
#
# Epoch 00011: val_loss did not improve
# Epoch 12/30
#  - 57s - loss: 0.0471 - acc: 0.9833 - val_loss: 0.0484 - val_acc: 0.9824
#
#  ROC-AUC - epoch: 12 - score: 0.985282
#
#
# Epoch 00012: val_loss did not improve
# Epoch 13/30
#  - 57s - loss: 0.0467 - acc: 0.9835 - val_loss: 0.0470 - val_acc: 0.9829
#
#  ROC-AUC - epoch: 13 - score: 0.985824
#
#
# Epoch 00013: val_loss improved from 0.04754 to 0.04699, saving model to ../snapshots/dpcnn_fasttext_128_fold_5.hdf5
# Epoch 14/30
#  - 57s - loss: 0.0464 - acc: 0.9837 - val_loss: 0.0478 - val_acc: 0.9825
#
#  ROC-AUC - epoch: 14 - score: 0.985236
#
#
# Epoch 00014: val_loss did not improve
# Epoch 15/30
#  - 57s - loss: 0.0463 - acc: 0.9836 - val_loss: 0.0489 - val_acc: 0.9829
#
#  ROC-AUC - epoch: 15 - score: 0.985266
#
#
# Epoch 00015: val_loss did not improve
# Epoch 16/30
#  - 58s - loss: 0.0457 - acc: 0.9837 - val_loss: 0.0476 - val_acc: 0.9828
#
#  ROC-AUC - epoch: 16 - score: 0.985183
#
#
# Epoch 00016: val_loss did not improve
# Epoch 17/30
#  - 58s - loss: 0.0457 - acc: 0.9838 - val_loss: 0.0488 - val_acc: 0.9827
#
#  ROC-AUC - epoch: 17 - score: 0.986178
#
#
# Epoch 00017: val_loss did not improve
# Epoch 18/30
#  - 58s - loss: 0.0455 - acc: 0.9839 - val_loss: 0.0478 - val_acc: 0.9821
#
#  ROC-AUC - epoch: 18 - score: 0.986067
#
#
# Epoch 00018: val_loss did not improve
# Epoch 00018: early stopping
# 153164/153164 [==============================] - 9s 58us/step
# Running fold 7 / 10
# Training / Valid set counts (151592,) / (7979,)
# Train on 151592 samples, validate on 7979 samples
# Epoch 1/30
#  - 69s - loss: 0.0743 - acc: 0.9785 - val_loss: 0.0580 - val_acc: 0.9810
#
#  ROC-AUC - epoch: 1 - score: 0.970517
#
#
# Epoch 00001: val_loss improved from inf to 0.05800, saving model to ../snapshots/dpcnn_fasttext_128_fold_6.hdf5
# Epoch 2/30
#  - 59s - loss: 0.0572 - acc: 0.9809 - val_loss: 0.0534 - val_acc: 0.9824
#
#  ROC-AUC - epoch: 2 - score: 0.964156
#
#
# Epoch 00002: val_loss improved from 0.05800 to 0.05344, saving model to ../snapshots/dpcnn_fasttext_128_fold_6.hdf5
# Epoch 3/30
#  - 58s - loss: 0.0543 - acc: 0.9816 - val_loss: 0.0542 - val_acc: 0.9819
#
#  ROC-AUC - epoch: 3 - score: 0.967993
#
#
# Epoch 00003: val_loss did not improve
# Epoch 4/30
#  - 58s - loss: 0.0532 - acc: 0.9818 - val_loss: 0.0539 - val_acc: 0.9817
#
#  ROC-AUC - epoch: 4 - score: 0.972684
#
#
# Epoch 00004: val_loss did not improve
# Epoch 5/30
#  - 58s - loss: 0.0519 - acc: 0.9822 - val_loss: 0.0491 - val_acc: 0.9830
#
#  ROC-AUC - epoch: 5 - score: 0.977414
#
#
# Epoch 00005: val_loss improved from 0.05344 to 0.04908, saving model to ../snapshots/dpcnn_fasttext_128_fold_6.hdf5
# Epoch 6/30
#  - 58s - loss: 0.0507 - acc: 0.9824 - val_loss: 0.0513 - val_acc: 0.9825
#
#  ROC-AUC - epoch: 6 - score: 0.981784
#
#
# Epoch 00006: val_loss did not improve
# Epoch 7/30
#  - 58s - loss: 0.0496 - acc: 0.9827 - val_loss: 0.0502 - val_acc: 0.9826
#
#  ROC-AUC - epoch: 7 - score: 0.979904
#
#
# Epoch 00007: val_loss did not improve
# Epoch 8/30
#  - 58s - loss: 0.0490 - acc: 0.9828 - val_loss: 0.0479 - val_acc: 0.9835
#
#  ROC-AUC - epoch: 8 - score: 0.982225
#
#
# Epoch 00008: val_loss improved from 0.04908 to 0.04788, saving model to ../snapshots/dpcnn_fasttext_128_fold_6.hdf5
# Epoch 9/30
#  - 59s - loss: 0.0483 - acc: 0.9829 - val_loss: 0.0491 - val_acc: 0.9829
#
#  ROC-AUC - epoch: 9 - score: 0.981441
#
#
# Epoch 00009: val_loss did not improve
# Epoch 10/30
#  - 58s - loss: 0.0478 - acc: 0.9831 - val_loss: 0.0494 - val_acc: 0.9830
#
#  ROC-AUC - epoch: 10 - score: 0.981016
#
#
# Epoch 00010: val_loss did not improve
# Epoch 11/30
#  - 59s - loss: 0.0476 - acc: 0.9832 - val_loss: 0.0504 - val_acc: 0.9830
#
#  ROC-AUC - epoch: 11 - score: 0.981417
#
#
# Epoch 00011: val_loss did not improve
# Epoch 12/30
#  - 58s - loss: 0.0472 - acc: 0.9832 - val_loss: 0.0489 - val_acc: 0.9831
#
#  ROC-AUC - epoch: 12 - score: 0.982367
#
#
# Epoch 00012: val_loss did not improve
# Epoch 13/30
#  - 58s - loss: 0.0469 - acc: 0.9833 - val_loss: 0.0480 - val_acc: 0.9835
#
#  ROC-AUC - epoch: 13 - score: 0.981195
#
#
# Epoch 00013: val_loss did not improve
# Epoch 00013: early stopping
# 153164/153164 [==============================] - 9s 58us/step
# Running fold 8 / 10
# Training / Valid set counts (151582,) / (7989,)
# Train on 151582 samples, validate on 7989 samples
# Epoch 1/30
#  - 70s - loss: 0.0758 - acc: 0.9784 - val_loss: 0.0574 - val_acc: 0.9811
#
#  ROC-AUC - epoch: 1 - score: 0.973520
#
#
# Epoch 00001: val_loss improved from inf to 0.05744, saving model to ../snapshots/dpcnn_fasttext_128_fold_7.hdf5
# Epoch 2/30
#  - 59s - loss: 0.0577 - acc: 0.9811 - val_loss: 0.0522 - val_acc: 0.9828
#
#  ROC-AUC - epoch: 2 - score: 0.975777
#
#
# Epoch 00002: val_loss improved from 0.05744 to 0.05219, saving model to ../snapshots/dpcnn_fasttext_128_fold_7.hdf5
# Epoch 3/30
#  - 59s - loss: 0.0546 - acc: 0.9818 - val_loss: 0.0527 - val_acc: 0.9827
#
#  ROC-AUC - epoch: 3 - score: 0.977780
#
#
# Epoch 00003: val_loss did not improve
# Epoch 4/30
#  - 59s - loss: 0.0530 - acc: 0.9822 - val_loss: 0.0516 - val_acc: 0.9829
#
#  ROC-AUC - epoch: 4 - score: 0.978577
#
#
# Epoch 00004: val_loss improved from 0.05219 to 0.05156, saving model to ../snapshots/dpcnn_fasttext_128_fold_7.hdf5
# Epoch 5/30
#  - 59s - loss: 0.0519 - acc: 0.9824 - val_loss: 0.0528 - val_acc: 0.9824
#
#  ROC-AUC - epoch: 5 - score: 0.979064
#
#
# Epoch 00005: val_loss did not improve
# Epoch 6/30
#  - 59s - loss: 0.0510 - acc: 0.9825 - val_loss: 0.0513 - val_acc: 0.9828
#
#  ROC-AUC - epoch: 6 - score: 0.980473
#
#
# Epoch 00006: val_loss improved from 0.05156 to 0.05132, saving model to ../snapshots/dpcnn_fasttext_128_fold_7.hdf5
# Epoch 7/30
#  - 57s - loss: 0.0500 - acc: 0.9828 - val_loss: 0.0500 - val_acc: 0.9833
#
#  ROC-AUC - epoch: 7 - score: 0.982419
#
#
# Epoch 00007: val_loss improved from 0.05132 to 0.04996, saving model to ../snapshots/dpcnn_fasttext_128_fold_7.hdf5
# Epoch 8/30
#  - 57s - loss: 0.0492 - acc: 0.9828 - val_loss: 0.0499 - val_acc: 0.9821
#
#  ROC-AUC - epoch: 8 - score: 0.983421
#
#
# Epoch 00008: val_loss improved from 0.04996 to 0.04993, saving model to ../snapshots/dpcnn_fasttext_128_fold_7.hdf5
# Epoch 9/30
#  - 57s - loss: 0.0487 - acc: 0.9829 - val_loss: 0.0488 - val_acc: 0.9835
#
#  ROC-AUC - epoch: 9 - score: 0.983203
#
#
# Epoch 00009: val_loss improved from 0.04993 to 0.04877, saving model to ../snapshots/dpcnn_fasttext_128_fold_7.hdf5
# Epoch 10/30
#  - 57s - loss: 0.0480 - acc: 0.9833 - val_loss: 0.0485 - val_acc: 0.9832
#
#  ROC-AUC - epoch: 10 - score: 0.984111
#
#
# Epoch 00010: val_loss improved from 0.04877 to 0.04849, saving model to ../snapshots/dpcnn_fasttext_128_fold_7.hdf5
# Epoch 11/30
#  - 57s - loss: 0.0475 - acc: 0.9832 - val_loss: 0.0478 - val_acc: 0.9835
#
#  ROC-AUC - epoch: 11 - score: 0.986112
#
#
# Epoch 00011: val_loss improved from 0.04849 to 0.04776, saving model to ../snapshots/dpcnn_fasttext_128_fold_7.hdf5
# Epoch 12/30
#  - 57s - loss: 0.0474 - acc: 0.9832 - val_loss: 0.0487 - val_acc: 0.9832
#
#  ROC-AUC - epoch: 12 - score: 0.984549
#
#
# Epoch 00012: val_loss did not improve
# Epoch 13/30
#  - 57s - loss: 0.0471 - acc: 0.9833 - val_loss: 0.0476 - val_acc: 0.9836
#
#  ROC-AUC - epoch: 13 - score: 0.986586
#
#
# Epoch 00013: val_loss improved from 0.04776 to 0.04756, saving model to ../snapshots/dpcnn_fasttext_128_fold_7.hdf5
# Epoch 14/30
#  - 57s - loss: 0.0465 - acc: 0.9833 - val_loss: 0.0480 - val_acc: 0.9831
#
#  ROC-AUC - epoch: 14 - score: 0.986532
#
#
# Epoch 00014: val_loss did not improve
# Epoch 15/30
#  - 57s - loss: 0.0462 - acc: 0.9835 - val_loss: 0.0506 - val_acc: 0.9834
#
#  ROC-AUC - epoch: 15 - score: 0.986433
#
#
# Epoch 00015: val_loss did not improve
# Epoch 16/30
#  - 57s - loss: 0.0460 - acc: 0.9835 - val_loss: 0.0479 - val_acc: 0.9830
#
#  ROC-AUC - epoch: 16 - score: 0.986906
#
#
# Epoch 00016: val_loss did not improve
# Epoch 17/30
#  - 57s - loss: 0.0457 - acc: 0.9836 - val_loss: 0.0495 - val_acc: 0.9829
#
#  ROC-AUC - epoch: 17 - score: 0.985715
#
#
# Epoch 00017: val_loss did not improve
# Epoch 18/30
#  - 57s - loss: 0.0458 - acc: 0.9836 - val_loss: 0.0488 - val_acc: 0.9824
#
#  ROC-AUC - epoch: 18 - score: 0.986418
#
#
# Epoch 00018: val_loss did not improve
# Epoch 00018: early stopping
# 153164/153164 [==============================] - 9s 58us/step
# Running fold 9 / 10
# Training / Valid set counts (151594,) / (7977,)
# Train on 151594 samples, validate on 7977 samples
# Epoch 1/30
#  - 68s - loss: 0.0745 - acc: 0.9787 - val_loss: 0.0599 - val_acc: 0.9814
#
#  ROC-AUC - epoch: 1 - score: 0.973492
#
#
# Epoch 00001: val_loss improved from inf to 0.05987, saving model to ../snapshots/dpcnn_fasttext_128_fold_8.hdf5
# Epoch 2/30
#  - 57s - loss: 0.0581 - acc: 0.9809 - val_loss: 0.0566 - val_acc: 0.9814
#
#  ROC-AUC - epoch: 2 - score: 0.975906
#
#
# Epoch 00002: val_loss improved from 0.05987 to 0.05664, saving model to ../snapshots/dpcnn_fasttext_128_fold_8.hdf5
# Epoch 3/30
#  - 57s - loss: 0.0549 - acc: 0.9815 - val_loss: 0.0520 - val_acc: 0.9832
#
#  ROC-AUC - epoch: 3 - score: 0.978743
#
#
# Epoch 00003: val_loss improved from 0.05664 to 0.05203, saving model to ../snapshots/dpcnn_fasttext_128_fold_8.hdf5
# Epoch 4/30
#  - 58s - loss: 0.0532 - acc: 0.9818 - val_loss: 0.0508 - val_acc: 0.9830
#
#  ROC-AUC - epoch: 4 - score: 0.980902
#
#
# Epoch 00004: val_loss improved from 0.05203 to 0.05077, saving model to ../snapshots/dpcnn_fasttext_128_fold_8.hdf5
# Epoch 5/30
#  - 58s - loss: 0.0520 - acc: 0.9822 - val_loss: 0.0500 - val_acc: 0.9832
#
#  ROC-AUC - epoch: 5 - score: 0.982815
#
#
# Epoch 00005: val_loss improved from 0.05077 to 0.04997, saving model to ../snapshots/dpcnn_fasttext_128_fold_8.hdf5
# Epoch 6/30
#  - 58s - loss: 0.0508 - acc: 0.9826 - val_loss: 0.0518 - val_acc: 0.9826
#
#  ROC-AUC - epoch: 6 - score: 0.983517
#
#
# Epoch 00006: val_loss did not improve
# Epoch 7/30
#  - 58s - loss: 0.0501 - acc: 0.9826 - val_loss: 0.0469 - val_acc: 0.9835
#
#  ROC-AUC - epoch: 7 - score: 0.984896
#
#
# Epoch 00007: val_loss improved from 0.04997 to 0.04692, saving model to ../snapshots/dpcnn_fasttext_128_fold_8.hdf5
# Epoch 8/30
#  - 58s - loss: 0.0491 - acc: 0.9828 - val_loss: 0.0498 - val_acc: 0.9838
#
#  ROC-AUC - epoch: 8 - score: 0.982546
#
#
# Epoch 00008: val_loss did not improve
# Epoch 9/30
#  - 58s - loss: 0.0482 - acc: 0.9831 - val_loss: 0.0479 - val_acc: 0.9839
#
#  ROC-AUC - epoch: 9 - score: 0.986330
#
#
# Epoch 00009: val_loss did not improve
# Epoch 10/30
#  - 58s - loss: 0.0480 - acc: 0.9831 - val_loss: 0.0476 - val_acc: 0.9837
#
#  ROC-AUC - epoch: 10 - score: 0.985726
#
#
# Epoch 00010: val_loss did not improve
# Epoch 11/30
#  - 58s - loss: 0.0474 - acc: 0.9830 - val_loss: 0.0478 - val_acc: 0.9838
#
#  ROC-AUC - epoch: 11 - score: 0.985985
#
#
# Epoch 00011: val_loss did not improve
# Epoch 12/30
#  - 58s - loss: 0.0468 - acc: 0.9833 - val_loss: 0.0478 - val_acc: 0.9835
#
#  ROC-AUC - epoch: 12 - score: 0.986516
#
#
# Epoch 00012: val_loss did not improve
# Epoch 00012: early stopping
# 153164/153164 [==============================] - 9s 59us/step
# Running fold 10 / 10
# Training / Valid set counts (151596,) / (7975,)
# Train on 151596 samples, validate on 7975 samples
# Epoch 1/30
#  - 70s - loss: 0.0735 - acc: 0.9789 - val_loss: 0.0531 - val_acc: 0.9825
#
#  ROC-AUC - epoch: 1 - score: 0.979848
#
#
# Epoch 00001: val_loss improved from inf to 0.05310, saving model to ../snapshots/dpcnn_fasttext_128_fold_9.hdf5
# Epoch 2/30
#  - 58s - loss: 0.0572 - acc: 0.9813 - val_loss: 0.0504 - val_acc: 0.9827
#
#  ROC-AUC - epoch: 2 - score: 0.979957
#
#
# Epoch 00002: val_loss improved from 0.05310 to 0.05040, saving model to ../snapshots/dpcnn_fasttext_128_fold_9.hdf5
# Epoch 3/30
#  - 58s - loss: 0.0547 - acc: 0.9815 - val_loss: 0.0491 - val_acc: 0.9830
#
#  ROC-AUC - epoch: 3 - score: 0.982489
#
#
# Epoch 00003: val_loss improved from 0.05040 to 0.04907, saving model to ../snapshots/dpcnn_fasttext_128_fold_9.hdf5
# Epoch 4/30
#  - 58s - loss: 0.0529 - acc: 0.9820 - val_loss: 0.0554 - val_acc: 0.9829
#
#  ROC-AUC - epoch: 4 - score: 0.978688
#
#
# Epoch 00004: val_loss did not improve
# Epoch 5/30
#  - 58s - loss: 0.0517 - acc: 0.9823 - val_loss: 0.0476 - val_acc: 0.9834
#
#  ROC-AUC - epoch: 5 - score: 0.986631
#
#
# Epoch 00005: val_loss improved from 0.04907 to 0.04764, saving model to ../snapshots/dpcnn_fasttext_128_fold_9.hdf5
# Epoch 6/30
#  - 59s - loss: 0.0505 - acc: 0.9824 - val_loss: 0.0463 - val_acc: 0.9837
#
#  ROC-AUC - epoch: 6 - score: 0.987321
#
#
# Epoch 00006: val_loss improved from 0.04764 to 0.04631, saving model to ../snapshots/dpcnn_fasttext_128_fold_9.hdf5
# Epoch 7/30
#  - 59s - loss: 0.0499 - acc: 0.9827 - val_loss: 0.0456 - val_acc: 0.9836
#
#  ROC-AUC - epoch: 7 - score: 0.988181
#
#
# Epoch 00007: val_loss improved from 0.04631 to 0.04556, saving model to ../snapshots/dpcnn_fasttext_128_fold_9.hdf5
# Epoch 8/30
#  - 59s - loss: 0.0492 - acc: 0.9829 - val_loss: 0.0465 - val_acc: 0.9836
#
#  ROC-AUC - epoch: 8 - score: 0.987687
#
#
# Epoch 00008: val_loss did not improve
# Epoch 9/30
#  - 59s - loss: 0.0483 - acc: 0.9830 - val_loss: 0.0458 - val_acc: 0.9834
#
#  ROC-AUC - epoch: 9 - score: 0.988194
#
#
# Epoch 00009: val_loss did not improve
# Epoch 10/30
#  - 58s - loss: 0.0481 - acc: 0.9832 - val_loss: 0.0468 - val_acc: 0.9838
#
#  ROC-AUC - epoch: 10 - score: 0.988690
#
#
# Epoch 00010: val_loss did not improve
# Epoch 11/30
#  - 58s - loss: 0.0473 - acc: 0.9834 - val_loss: 0.0464 - val_acc: 0.9838
#
#  ROC-AUC - epoch: 11 - score: 0.988716
#
#
# Epoch 00011: val_loss did not improve
# Epoch 12/30
#  - 58s - loss: 0.0471 - acc: 0.9835 - val_loss: 0.0460 - val_acc: 0.9831
#
#  ROC-AUC - epoch: 12 - score: 0.989453
#
#
# Epoch 00012: val_loss did not improve
# Epoch 00012: early stopping
# 153164/153164 [==============================] - 9s 60us/step

# %%
y_pred = model.predict(x_test)
submission = pd.read_csv('../input/jigsaw-toxic-comment-classification-challenge/sample_submission.csv')
submission[["toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"]] = y_pred
submission.to_csv('dpcnn_test_preds.csv', index=False)
